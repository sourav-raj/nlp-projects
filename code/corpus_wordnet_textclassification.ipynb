# %%
# -*- coding: utf-8 -*-
# Indentation: Jupyter Notebook

'''
Corpus Wordnet text Classification
'''

__version__ = 1.0
__author__ = "Sourav Raj"
__author_email__ = "souravraj.iitbbs@gmail.com"

# %%
import nltk
print(nltk.__file__)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\nltk\__init__.py

# %%
nltk.download("gutenberg")
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\ProgramData\Anaconda2\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# True

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# %%
sample = gutenberg.raw("bible-kjv.txt")

# %%
tok = sent_tokenize(sample)

# %%
print(tok[5:15])
# Out:
# [u'1:5 And God called the light Day, and the darkness he called Night.', u'And the evening and the morning were the first day.', u'1:6 And God said, Let there be a firmament in the midst of the waters,\nand let it divide the waters from the waters.', u'1:7 And God made the firmament, and divided the waters which were\nunder the firmament from the waters which were above the firmament:\nand it was so.', u'1:8 And God called the firmament Heaven.', u'And the evening and the\nmorning were the second day.', u'1:9 And God said, Let the waters under the heaven be gathered together\nunto one place, and let the dry land appear: and it was so.', u'1:10 And God called the dry land Earth; and the gathering together of\nthe waters called he Seas: and God saw that it was good.', u'1:11 And God said, Let the earth bring forth grass, the herb yielding\nseed, and the fruit tree yielding fruit after his kind, whose seed is\nin itself, upon the earth: and it was so.', u'1:12 And the earth brought forth grass, and herb yielding seed after\nhis kind, and the tree yielding fruit, whose seed was in itself, after\nhis kind: and God saw that it was good.']

# %%
from nltk.corpus import wordnet

# %%
syns = wordnet.synsets("program")

# %%
print(syns)
# Out:
# [Synset('plan.n.01'), Synset('program.n.02'), Synset('broadcast.n.02'), Synset('platform.n.02'), Synset('program.n.05'), Synset('course_of_study.n.01'), Synset('program.n.07'), Synset('program.n.08'), Synset('program.v.01'), Synset('program.v.02')]

# %%
print(syns[0])
# Out:
# Synset('plan.n.01')

# %%
print(syns[0].lemmas())
# Out:
# [Lemma('plan.n.01.plan'), Lemma('plan.n.01.program'), Lemma('plan.n.01.programme')]

# %%
print(syns[0].lemmas()[0].name())
# Out:
# plan

# %%
print(syns[0]).name()
# Out:
# plan.n.01

# %%
print(syns[0].definition())
# Out:
# a series of steps to be carried out or goals to be accomplished

# %%
print(syns[0].examples())
# Out:
# [u'they drew up a six-step plan', u'they discussed plans for a new bond issue']

# %%
synonyms=[]
antonyms=[]

# %%
for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
print(set(synonyms))
print(set(antonyms))
# Out:
# set([u'beneficial', u'right', u'secure', u'just', u'unspoilt', u'respectable', u'good', u'goodness', u'dear', u'salutary', u'ripe', u'expert', u'skillful', u'in_force', u'proficient', u'unspoiled', u'dependable', u'soundly', u'honorable', u'full', u'undecomposed', u'safe', u'adept', u'upright', u'trade_good', u'sound', u'in_effect', u'practiced', u'effective', u'commodity', u'estimable', u'well', u'honest', u'near', u'skilful', u'thoroughly', u'serious'])
# set([u'bad', u'badness', u'ill', u'evil', u'evilness'])

# %%
w1 = wordnet.synset("ship.n.01")
w2= wordnet.synset("boat.n.01")

# %%
print(w1.wup_similarity(w2))
# Out:
# 0.909090909091

# %%
w1 = wordnet.synset("ship.n.01")
w2= wordnet.synset("car.n.01")
print(w1.wup_similarity(w2))

w1 = wordnet.synset("ship.n.01")
w2= wordnet.synset("cat.n.01")
print(w1.wup_similarity(w2))

w1 = wordnet.synset("ship.n.01")
w2= wordnet.synset("cactus.n.01")
print(w1.wup_similarity(w2))
# Out:
# 0.695652173913
# 0.32
# 0.380952380952

# %% [markdown]
# # Text Classification

# %%
import nltk
import random
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

# %%
random.shuffle(documents)

# %%
#documents = []
#for category in movie_reviews.categories():
#    for fileid in movie_reviews.fileids(category):
        #x = list(movie_reviews.words(fileid))
        #x.append(category)
        #documents.append(x)
        #documents.append(list(movie_reviews.words(fileid)), category)

# %%
documents.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e2f4559ca117> in <module>()
# ----> 1 documents.dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
documents[:2]
# Out:
# [([u'ingredients',
#    u':',
#    u'possessed',
#    u'plastic',
#    u'dolls',
#    u'in',
#    u'love',
#    u',',
#    u'plastic',
#    u'dolls',
#    u'having',
#    u'sex',
#    u'starring',
#    u':',
#    u'jennifer',
#    u'tilly',
#    u',',
#    u'voice',
#    u'of',
#    u'brad',
#    u'dourif',
#    u',',
#    u'katherine',
#    u'heigl',
#    u',',
#    u'nick',
#    u'stabile',
#    u',',
#    u'john',
#    u'ritter',
#    u'synopsis',
#    u':',
#    u'this',
#    u'is',
#    u'the',
#    u'fourth',
#    u'film',
#    u'in',
#    u'the',
#    u'chucky',
#    u'series',
#    u',',
#    u'which',
#    u'debuted',
#    u'in',
#    u'the',
#    u'late',
#    u'1980s',
#    u'.',
#    u'basically',
#    u',',
#    u'chucky',
#    u'is',
#    u'a',
#    u'plastic',
#    u'doll',
#    u'that',
#    u'can',
#    u'walk',
#    u'and',
#    u'talk',
#    u'because',
#    u'it',
#    u'is',
#    u'possessed',
#    u'by',
#    u'the',
#    u'spirit',
#    u'of',
#    u'a',
#    u'slain',
#    u'murderer',
#    u'.',
#    u'in',
#    u'bride',
#    u'of',
#    u'chucky',
#    u',',
#    u'chucky',
#    u"'",
#    u's',
#    u'longtime',
#    u'girlfriend',
#    u'tiffany',
#    u'(',
#    u'jennifer',
#    u'tilly',
#    u')',
#    u'dies',
#    u'and',
#    u'her',
#    u'spirit',
#    u'inhabits',
#    u'a',
#    u'female',
#    u'plastic',
#    u'doll',
#    u'through',
#    u'voodoo',
#    u'.',
#    u'dolls',
#    u'tiffany',
#    u'and',
#    u'chucky',
#    u'get',
#    u'married',
#    u'and',
#    u'embark',
#    u'on',
#    u'a',
#    u'quest',
#    u'to',
#    u'reach',
#    u'a',
#    u'cemetery',
#    u'in',
#    u'new',
#    u'jersey',
#    u',',
#    u'where',
#    u'a',
#    u'mystical',
#    u'gem',
#    u'might',
#    u'enable',
#    u'them',
#    u'to',
#    u'be',
#    u'humans',
#    u'.',
#    u'the',
#    u'dolls',
#    u'stow',
#    u'away',
#    u'in',
#    u'the',
#    u'back',
#    u'of',
#    u'a',
#    u'vehicle',
#    u'driven',
#    u'by',
#    u'a',
#    u'newly',
#    u'eloped',
#    u'couple',
#    u',',
#    u'so',
#    u'in',
#    u'the',
#    u'side',
#    u'plot',
#    u',',
#    u'the',
#    u'couple',
#    u'suspects',
#    u'each',
#    u'other',
#    u'of',
#    u'being',
#    u'a',
#    u'murderer',
#    u'.',
#    u'opinion',
#    u':',
#    u'bride',
#    u'of',
#    u'chucky',
#    u'is',
#    u'an',
#    u'attempt',
#    u'at',
#    u'horror',
#    u'with',
#    u'humor',
#    u',',
#    u'but',
#    u'doesn',
#    u"'",
#    u't',
#    u'succeed',
#    u'.',
#    u'somehow',
#    u',',
#    u'chucky',
#    u'moaning',
#    u'about',
#    u'mid',
#    u'life',
#    u'crisis',
#    u',',
#    u'and',
#    u'how',
#    u'he',
#    u'should',
#    u'have',
#    u'gotten',
#    u'married',
#    u'does',
#    u'not',
#    u'make',
#    u'for',
#    u'a',
#    u'very',
#    u'scary',
#    u'chucky',
#    u'.',
#    u'and',
#    u'tiffany',
#    u'harping',
#    u'about',
#    u'mid',
#    u'life',
#    u'crisis',
#    u',',
#    u'and',
#    u'how',
#    u'she',
#    u'should',
#    u'have',
#    u'gotten',
#    u'married',
#    u'does',
#    u'not',
#    u'make',
#    u'for',
#    u'a',
#    u'very',
#    u'scary',
#    u'tiffany',
#    u'.',
#    u'the',
#    u'suspenseless',
#    u'bride',
#    u'of',
#    u'chucky',
#    u'relies',
#    u'mostly',
#    u'on',
#    u'jennifer',
#    u'tilly',
#    u"'",
#    u's',
#    u'cleavage',
#    u'to',
#    u'keep',
#    u'attention',
#    u'during',
#    u'the',
#    u'first',
#    u'half',
#    u',',
#    u'and',
#    u'on',
#    u'occasional',
#    u'puns',
#    u'to',
#    u'keep',
#    u'attention',
#    u'during',
#    u'the',
#    u'second',
#    u'half',
#    u'.',
#    u'the',
#    u'best',
#    u'that',
#    u'can',
#    u'be',
#    u'said',
#    u'about',
#    u'bride',
#    u'of',
#    u'chucky',
#    u'is',
#    u'that',
#    u'it',
#    u'is',
#    u'sarcastic',
#    u'.'],
#   u'neg'),
#  ([u'martial',
#    u'arts',
#    u'master',
#    u'steven',
#    u'seagal',
#    u'(',
#    u'not',
#    u'to',
#    u'mention',
#    u'director',
#    u'!',
#    u')',
#    u'has',
#    u'built',
#    u'a',
#    u'career',
#    u'out',
#    u'of',
#    u'playing',
#    u'an',
#    u'allegedly',
#    u'fictitious',
#    u'martial',
#    u'arts',
#    u'superman',
#    u'who',
#    u'never',
#    u'gets',
#    u'hurt',
#    u'in',
#    u'fights',
#    u',',
#    u'talks',
#    u'in',
#    u'a',
#    u'hushed',
#    u'tone',
#    u',',
#    u'and',
#    u'squints',
#    u'at',
#    u'any',
#    u'sign',
#    u'of',
#    u'danger',
#    u'.',
#    u'he',
#    u"'",
#    u's',
#    u'also',
#    u'the',
#    u'most',
#    u'consistent',
#    u'individual',
#    u'in',
#    u'hollywood',
#    u'today',
#    u',',
#    u'since',
#    u'all',
#    u'his',
#    u'movies',
#    u'suck',
#    u'.',
#    u'they',
#    u'basically',
#    u'represent',
#    u'his',
#    u'egotisitical',
#    u'tendencies',
#    u'about',
#    u'his',
#    u'art',
#    u'(',
#    u'that',
#    u'is',
#    u',',
#    u'martial',
#    u'art',
#    u')',
#    u'.',
#    u'i',
#    u"'",
#    u'm',
#    u'sure',
#    u'the',
#    u'guy',
#    u"'",
#    u's',
#    u'good',
#    u',',
#    u'and',
#    u'he',
#    u'seems',
#    u'like',
#    u'a',
#    u'nice',
#    u'guy',
#    u'on',
#    u'talk',
#    u'shows',
#    u',',
#    u'although',
#    u'a',
#    u'tad',
#    u'haughty',
#    u',',
#    u'but',
#    u'these',
#    u'movies',
#    u'he',
#    u'makes',
#    u'are',
#    u'all',
#    u'the',
#    u'same',
#    u':',
#    u'a',
#    u'guy',
#    u'who',
#    u'is',
#    u'basically',
#    u'indestructable',
#    u',',
#    u'is',
#    u'maybe',
#    u'wounded',
#    u'supposedly',
#    u'mortally',
#    u',',
#    u'then',
#    u'comes',
#    u'back',
#    u'with',
#    u'a',
#    u'vengeance',
#    u'and',
#    u'goes',
#    u'buddha',
#    u'on',
#    u'all',
#    u'the',
#    u'baddies',
#    u'asses',
#    u'(',
#    u'although',
#    u'i',
#    u'kinda',
#    u'liked',
#    u'"',
#    u'under',
#    u'siege',
#    u'"',
#    u')',
#    u'.',
#    u'of',
#    u'course',
#    u',',
#    u'this',
#    u'one',
#    u',',
#    u'as',
#    u'a',
#    u'change',
#    u',',
#    u'has',
#    u'a',
#    u'"',
#    u'message',
#    u'"',
#    u'that',
#    u'is',
#    u'drilled',
#    u'into',
#    u'our',
#    u'mind',
#    u'.',
#    u'.',
#    u'.',
#    u'of',
#    u'course',
#    u',',
#    u'after',
#    u'he',
#    u'blows',
#    u'up',
#    u'a',
#    u'lot',
#    u'of',
#    u'stuff',
#    u'and',
#    u'kills',
#    u'a',
#    u'bunch',
#    u'of',
#    u'people',
#    u'.',
#    u'so',
#    u'why',
#    u'do',
#    u'i',
#    u'watch',
#    u'his',
#    u'crap',
#    u'?',
#    u'i',
#    u'usually',
#    u'don',
#    u"'",
#    u't',
#    u'.',
#    u'i',
#    u'will',
#    u'never',
#    u',',
#    u'and',
#    u'you',
#    u'can',
#    u'hold',
#    u'me',
#    u'to',
#    u'this',
#    u',',
#    u'i',
#    u'will',
#    u'never',
#    u'pay',
#    u'to',
#    u'see',
#    u'this',
#    u'man',
#    u"'",
#    u's',
#    u'movies',
#    u',',
#    u'unless',
#    u',',
#    u'and',
#    u'only',
#    u'unless',
#    u',',
#    u'he',
#    u"'",
#    u's',
#    u'in',
#    u'a',
#    u'supporting',
#    u'role',
#    u'(',
#    u'i',
#    u'.',
#    u'e',
#    u'.',
#    u'"',
#    u'executive',
#    u'decision',
#    u'"',
#    u')',
#    u'and',
#    u'i',
#    u"'",
#    u'd',
#    u'definitely',
#    u'pay',
#    u'if',
#    u'he',
#    u'dies',
#    u'(',
#    u'i',
#    u'.',
#    u'e',
#    u'.',
#    u'"',
#    u'executive',
#    u'decision',
#    u'"',
#    u')',
#    u'.',
#    u'but',
#    u'this',
#    u'one',
#    u'has',
#    u'a',
#    u'special',
#    u'place',
#    u'in',
#    u'my',
#    u'heart',
#    u'.',
#    u'this',
#    u'doesn',
#    u"'",
#    u't',
#    u'mean',
#    u'it',
#    u"'",
#    u's',
#    u'good',
#    u'or',
#    u'that',
#    u'i',
#    u'even',
#    u'liked',
#    u'it',
#    u'.',
#    u'this',
#    u'was',
#    u'the',
#    u'last',
#    u'movie',
#    u'i',
#    u'watched',
#    u'with',
#    u'my',
#    u'deceased',
#    u'uncle',
#    u',',
#    u'and',
#    u'we',
#    u'had',
#    u'one',
#    u'hell',
#    u'of',
#    u'a',
#    u'time',
#    u'ripping',
#    u'it',
#    u'apart',
#    u'a',
#    u'la',
#    u'"',
#    u'mystery',
#    u'science',
#    u'theatre',
#    u'3000',
#    u',',
#    u'"',
#    u'and',
#    u'this',
#    u'was',
#    u'a',
#    u'couple',
#    u'years',
#    u'before',
#    u'i',
#    u'had',
#    u'heard',
#    u'of',
#    u'"',
#    u'mystery',
#    u'science',
#    u'theatre',
#    u'3000',
#    u'.',
#    u'"',
#    u'in',
#    u'this',
#    u'one',
#    u',',
#    u'seagal',
#    u'plays',
#    u'a',
#    u'worker',
#    u'for',
#    u'a',
#    u'mining',
#    u'factory',
#    u'set',
#    u'in',
#    u'alaska',
#    u'and',
#    u'run',
#    u'by',
#    u'the',
#    u'greased',
#    u'-',
#    u'up',
#    u'typical',
#    u'shallow',
#    u'villain',
#    u',',
#    u'this',
#    u'time',
#    u'played',
#    u'by',
#    u'an',
#    u'oscar',
#    u'-',
#    u'winner',
#    u'to',
#    u'give',
#    u'the',
#    u'movie',
#    u'some',
#    u'more',
#    u'clout',
#    u'-',
#    u'michael',
#    u'caine',
#    u'.',
#    u'it',
#    u'seems',
#    u'that',
#    u'caine',
#    u'wants',
#    u'to',
#    u'do',
#    u'something',
#    u'with',
#    u'his',
#    u'oil',
#    u'factory',
#    u'that',
#    u'includes',
#    u'him',
#    u'dumping',
#    u'oil',
#    u'all',
#    u'over',
#    u'inuit',
#    u'land',
#    u'.',
#    u'around',
#    u'the',
#    u'20',
#    u'-',
#    u'30',
#    u'minute',
#    u'point',
#    u',',
#    u'seagal',
#    u'speaks',
#    u'up',
#    u'to',
#    u'him',
#    u'in',
#    u'what',
#    u'seems',
#    u'to',
#    u'be',
#    u'the',
#    u'typical',
#    u'speech',
#    u'to',
#    u'all',
#    u'the',
#    u'vain',
#    u'entrepeneurs',
#    u'(',
#    u'what',
#    u'with',
#    u'his',
#    u'new',
#    u'"',
#    u'fire',
#    u'down',
#    u'below',
#    u',',
#    u'"',
#    u'another',
#    u'"',
#    u'message',
#    u'film',
#    u'"',
#    u')',
#    u',',
#    u'and',
#    u'caine',
#    u'has',
#    u'him',
#    u'bumped',
#    u'off',
#    u'.',
#    u'.',
#    u'.',
#    u'or',
#    u'does',
#    u'he',
#    u'?',
#    u'seagal',
#    u'is',
#    u'rescued',
#    u'by',
#    u'some',
#    u'inuits',
#    u',',
#    u'and',
#    u'falls',
#    u'in',
#    u'love',
#    u'with',
#    u'one',
#    u'of',
#    u'them',
#    u',',
#    u'played',
#    u'by',
#    u'joan',
#    u'chen',
#    u',',
#    u'who',
#    u'can',
#    u'act',
#    u',',
#    u'hypothetically',
#    u',',
#    u'but',
#    u',',
#    u'for',
#    u'some',
#    u'reason',
#    u',',
#    u'not',
#    u'here',
#    u'.',
#    u'one',
#    u'of',
#    u'caine',
#    u"'",
#    u's',
#    u'cliched',
#    u'henchmen',
#    u'(',
#    u'played',
#    u'here',
#    u'with',
#    u'a',
#    u'lot',
#    u'of',
#    u'overacting',
#    u'by',
#    u'john',
#    u'c',
#    u'.',
#    u'mcginley',
#    u')',
#    u'shoots',
#    u'the',
#    u'cheif',
#    u'of',
#    u'the',
#    u'inuit',
#    u'clan',
#    u',',
#    u'and',
#    u'chen',
#    u'and',
#    u'seagal',
#    u'go',
#    u'on',
#    u'a',
#    u'voyage',
#    u'to',
#    u'take',
#    u'down',
#    u'the',
#    u'oil',
#    u'factory',
#    u'.',
#    u'.',
#    u'.',
#    u'literally',
#    u',',
#    u'of',
#    u'course',
#    u'.',
#    u'at',
#    u'one',
#    u'point',
#    u',',
#    u'seagal',
#    u'gives',
#    u'a',
#    u'wonderfully',
#    u'hysterical',
#    u'speech',
#    u'about',
#    u'how',
#    u'he',
#    u'doesn',
#    u"'",
#    u't',
#    u'have',
#    u'any',
#    u'options',
#    u'but',
#    u'blow',
#    u'stuff',
#    u'up',
#    u'.',
#    u'he',
#    u'even',
#    u'goes',
#    u'as',
#    u'far',
#    u'as',
#    u'to',
#    u'say',
#    u',',
#    u'"',
#    u'i',
#    u'don',
#    u"'",
#    u't',
#    u'want',
#    u'to',
#    u'kill',
#    u'someone',
#    u',',
#    u'"',
#    u'and',
#    u'in',
#    u'the',
#    u'same',
#    u'breath',
#    u',',
#    u'he',
#    u'asks',
#    u'some',
#    u'guy',
#    u'where',
#    u'the',
#    u'arsenal',
#    u'is',
#    u'.',
#    u'i',
#    u'have',
#    u'no',
#    u'problem',
#    u'with',
#    u'violence',
#    u'.',
#    u'i',
#    u"'",
#    u'm',
#    u'a',
#    u'huge',
#    u'john',
#    u'woo',
#    u'fan',
#    u',',
#    u'but',
#    u'he',
#    u'paints',
#    u'his',
#    u'films',
#    u'with',
#    u'suspense',
#    u',',
#    u'skill',
#    u',',
#    u'style',
#    u',',
#    u'depth',
#    u',',
#    u'characterization',
#    u',',
#    u'and',
#    u'just',
#    u'plain',
#    u'cool',
#    u'violence',
#    u'.',
#    u'in',
#    u'the',
#    u'films',
#    u'of',
#    u'seagal',
#    u',',
#    u'the',
#    u'suspense',
#    u'mainly',
#    u'consists',
#    u'of',
#    u'the',
#    u'baddie',
#    u'attacking',
#    u'him',
#    u'stupidly',
#    u',',
#    u'and',
#    u'him',
#    u'either',
#    u'wounding',
#    u'or',
#    u'killing',
#    u'them',
#    u'.',
#    u'at',
#    u'some',
#    u'points',
#    u',',
#    u'they',
#    u'use',
#    u'the',
#    u'cliche',
#    u'of',
#    u'the',
#    u'talking',
#    u'villain',
#    u',',
#    u'where',
#    u'the',
#    u'villain',
#    u'has',
#    u'the',
#    u'advantage',
#    u',',
#    u'can',
#    u'shoot',
#    u'seagal',
#    u',',
#    u'but',
#    u'begins',
#    u'talking',
#    u'by',
#    u'either',
#    u'telling',
#    u'him',
#    u'his',
#    u'big',
#    u'secret',
#    u'plan',
#    u',',
#    u'or',
#    u'saying',
#    u'a',
#    u'corny',
#    u'line',
#    u',',
#    u'to',
#    u'which',
#    u'seagal',
#    u'says',
#    u'something',
#    u'hokey',
#    u'back',
#    u',',
#    u'and',
#    u'has',
#    u'had',
#    u'enough',
#    u'time',
#    u'to',
#    u'devise',
#    u'of',
#    u'a',
#    u'way',
#    u'to',
#    u'do',
#    u'away',
#    u'with',
#    u'them',
#    u',',
#    u'and',
#    u'does',
#    u'.',
#    u'this',
#    u'would',
#    u'be',
#    u'okay',
#    u'if',
#    u'there',
#    u'were',
#    u'any',
#    u'suspense',
#    u'or',
#    u'if',
#    u'it',
#    u'didn',
#    u"'",
#    u't',
#    u'take',
#    u'itself',
#    u'seriously',
#    u'at',
#    u'all',
#    u',',
#    u'like',
#    u'in',
#    u'the',
#    u'case',
#    u'of',
#    u'this',
#    u'summer',
#    u"'",
#    u's',
#    u'"',
#    u'con',
#    u'air',
#    u'.',
#    u'"',
#    u'but',
#    u'seagal',
#    u'is',
#    u'serious',
#    u'about',
#    u'his',
#    u'skill',
#    u',',
#    u'and',
#    u'of',
#    u'course',
#    u',',
#    u'his',
#    u'message',
#    u'.',
#    u'i',
#    u'wouldn',
#    u"'",
#    u't',
#    u'mind',
#    u'if',
#    u'this',
#    u'was',
#    u'a',
#    u'message',
#    u'film',
#    u'in',
#    u'the',
#    u'way',
#    u'that',
#    u'they',
#    u'present',
#    u'it',
#    u'to',
#    u'you',
#    u'with',
#    u'evidence',
#    u'.',
#    u'but',
#    u'seagal',
#    u'has',
#    u'no',
#    u'idea',
#    u'how',
#    u'to',
#    u'present',
#    u'a',
#    u'film',
#    u'where',
#    u'the',
#    u'message',
#    u'is',
#    u'subtle',
#    u',',
#    u'not',
#    u'pounded',
#    u'into',
#    u'the',
#    u'viewer',
#    u"'",
#    u's',
#    u'mind',
#    u'.',
#    u'the',
#    u'villain',
#    u'is',
#    u'totally',
#    u'shallow',
#    u'and',
#    u'cartoonish',
#    u',',
#    u'thus',
#    u'we',
#    u'can',
#    u"'",
#    u't',
#    u'take',
#    u'him',
#    u'and',
#    u'his',
#    u'motives',
#    u'seriously',
#    u',',
#    u'and',
#    u'while',
#    u'seagal',
#    u'talks',
#    u'about',
#    u'being',
#    u'kind',
#    u'to',
#    u'the',
#    u'environment',
#    u',',
#    u'he',
#    u'also',
#    u'goes',
#    u'ahead',
#    u'and',
#    u'blows',
#    u'up',
#    u'a',
#    u'square',
#    u'mile',
#    u'of',
#    u'rig',
#    u',',
#    u'and',
#    u'kills',
#    u'some',
#    u'workers',
#    u'who',
#    u'were',
#    u'just',
#    u'doing',
#    u'his',
#    u'job',
#    u'.',
#    u'then',
#    u'at',
#    u'the',
#    u'end',
#    u',',
#    u'he',
#    u'spends',
#    u'a',
#    u'good',
#    u'10',
#    u'minutes',
#    u'giving',
#    u'a',
#    u'speech',
#    u',',
#    u'just',
#    u'in',
#    u'case',
#    u'you',
#    u'didn',
#    u"'",
#    u't',
#    u'get',
#    u'the',
#    u'message',
#    u'from',
#    u'the',
#    u'trailers',
#    u'.',
#    u'what',
#    u'seagal',
#    u'doesn',
#    u"'",
#    u't',
#    u'realize',
#    u'is',
#    u'that',
#    u'no',
#    u'one',
#    u'takes',
#    u'his',
#    u'films',
#    u'seriously',
#    u'(',
#    u'although',
#    u'maybe',
#    u'a',
#    u'couple',
#    u'do',
#    u')',
#    u'and',
#    u'any',
#    u'message',
#    u'he',
#    u'has',
#    u'is',
#    u'no',
#    u'only',
#    u'redundant',
#    u',',
#    u'but',
#    u'doesn',
#    u"'",
#    u't',
#    u'comfortably',
#    u'fit',
#    u'in',
#    u'his',
#    u'film',
#    u',',
#    u'which',
#    u'is',
#    u'filled',
#    u'to',
#    u'the',
#    u'brim',
#    u'with',
#    u'hokey',
#    u'violence',
#    u',',
#    u'crap',
#    u'suspense',
#    u',',
#    u'stupid',
#    u'melodrama',
#    u',',
#    u'and',
#    u'characters',
#    u'who',
#    u'have',
#    ...],
#   u'neg')]

# %%
all_words =[]
for w in movie_reviews.words():
    all_words.append(w.lower())

# %%
all_words[:30]
# Out:
# [u'plot',
#  u':',
#  u'two',
#  u'teen',
#  u'couples',
#  u'go',
#  u'to',
#  u'a',
#  u'church',
#  u'party',
#  u',',
#  u'drink',
#  u'and',
#  u'then',
#  u'drive',
#  u'.',
#  u'they',
#  u'get',
#  u'into',
#  u'an',
#  u'accident',
#  u'.',
#  u'one',
#  u'of',
#  u'the',
#  u'guys',
#  u'dies',
#  u',',
#  u'but',
#  u'his']

# %%
all_words = nltk.FreqDist(all_words)
print(all_words.most_common(15))
# Out:
# [(u',', 77717), (u'the', 76529), (u'.', 65876), (u'a', 38106), (u'and', 35576), (u'of', 34123), (u'to', 31937), (u"'", 30585), (u'is', 25195), (u'in', 21822), (u's', 18513), (u'"', 17612), (u'it', 16107), (u'that', 15924), (u'-', 15595)]

# %%
print(all_words["stupid"])
# Out:
# 253

# %% [markdown]
#  Words as feature for learning

# %%
word_features = list(all_words.keys())[:3000]

# %%
def find_features(document):
    words= set(document)
    features={}
    for w in word_features:
        features[w]=(w in words)
    return features

# %%
print(find_features(movie_reviews.words('C:/ProgramData/Anaconda2/nltk_data/corpora/movie_reviews/neg/cv000_29416.txt')))
# Out:
# {u'clamoring': False, u'madsen': False, u'sonja': False, u'four': False, u'woods': False, u'spiders': False, u'gavan': False, u'francesco': False, u'francesca': False, u'fedoore': False, u'comically': False, u'localized': False, u'conjure': False, u'stinks': False, u'disobeying': False, u'hennings': False, u'porno': False, u'canet': False, u'seduction': False, u'stinky': False, u'scold': False, u'originality': False, u'neighbours': False, u'caned': False, u'sexualized': False, u'rickman': False, u'worth': False, u'porns': False, u'alternating': False, u'amorous': False, u'copasetic': False, u'slothful': False, u'wracked': False, u'dougnac': False, u'aurora': False, u'stipulate': False, u'kissed_': False, u'helgenberger': False, u'capoeira': False, u'rosalba': False, u'tantalizing': False, u'rawhide': False, u'summarized': False, u'screaming': False, u'yikes': False, u'basics': False, u'liaisons': False, u'grueling': False, u'sommerset': False, u'investigator': False, u'wooden': False, u'wednesday': False, u'broiled': False, u'samurai': False, u'circuitry': False, u'notifying': False, u'crotch': False, u'elgar': False, u'stereotypical': False, u'monologue': False, u'busybody': False, u'roldan': False, u'jamaica': False, u'bazooms': False, u'sabbato': False, u'snuggles': False, u'hanging': False, u'pescara': False, u'feasibility': False, u'miniatures': False, u'nerdiest': False, u'mesmerising': False, u'gorman': False, u'woody': False, u'consenting': False, u'scraped': False, u'gazon': False, u'machines': False, u'inanimate': False, u'errors': False, u'contemplates': False, u'rekindle': False, u'offshoots': False, u'cooking': False, u'fonzie': False, u'petri': False, u'joely': False, u'outfielders': False, u'numeral': False, u'succumb': False, u'shocks': False, u'personifies': False, u'viewings': False, u'chins': False, u'menage': False, u'jubilantly': False, u'rocque': False, u'spunky': False, u'dilapidating': False, u'equals': False, u'bangkok': False, u'thrash': False, u'ching': False, u'protection': False, u'china': False, u'personified': False, u'dobie': False, u'shandling': False, u'wiseguy': False, u'natured': False, u'watermelons': False, u'kids': True, u'uplifting': False, u'elaborate': False, u'controversy': False, u'rebhorn': False, u'crowdpleasing': False, u'stressed': False, u'neurologist': False, u'advantages': False, u'spotty': False, u'climber': False, u'appropriately': False, u'cobblers': False, u'projection': False, u'urbaniak': False, u'outraging': False, u'brs': False, u'lengthen': False, u'emerich': False, u'replace': False, u'bro': False, u'lavatory': False, u'archaeological': False, u'unsinkable': False, u'stern': False, u'compulsively': False, u'cocaine': False, u'kethcum': False, u'sarah': False, u'plot': True, u'plow': False, u'dna': False, u'plop': False, u'catchy': False, u'insecurity': False, u'sweater': False, u'coins': False, u'ploy': False, u'cannibal': False, u'sidebars': False, u'coordinators': False, u'music': True, u'therefore': False, u'superweapons': False, u'mutinies': False, u'bundled': False, u'magyuver': False, u'separated': False, u'deloreans': False, u'bombast': False, u'writihing': False, u'kohn': False, u'mesmerize': False, u'ascribe': False, u'yahoo': False, u'exuberantly': False, u'sputter': False, u'championships': False, u'boorman': False, u'separates': False, u'provide': False, u'foregrounds': False, u'primeval': False, u'conditioned': False, u'voicework': False, u'blocking': False, u'circumstances': False, u'reingold': False, u'tnt': False, u'1993': False, u'morally': False, u'locked': False, u'1994': False, u'daqughter': False, u'1996': False, u'1999': False, u'1998': False, u'elicit': False, u'cuddly': False, u'divorces': False, u'locker': False, u'tissue': False, u'locket': False, u'era': False, u'soundbite': False, u'gershon': False, u'elbow': False, u'erm': False, u'ern': False, u'revenues': False, u'hinting': False, u'scripting': False, u'matilda': False, u'wang': False,  ...

# %%
featuresets=[(find_features(rev), category) for (rev, category) in documents]

# %%
training_set = featuresets[:1900]
testing_set = featuresets[1900:]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
print (nltk.classify.accuracy(classifier, testing_set))*100
classifier.show_most_informative_features(15)
# Out:
# 66.0
# Most Informative Features
#                insulting = True              neg : pos    =     11.0 : 1.0
#                     sans = True              neg : pos    =      9.0 : 1.0
#                uplifting = True              pos : neg    =      8.6 : 1.0
#             refreshingly = True              pos : neg    =      8.3 : 1.0
#                  wasting = True              neg : pos    =      7.7 : 1.0
#                  detract = True              pos : neg    =      7.0 : 1.0
#                dismissed = True              pos : neg    =      7.0 : 1.0
#              bruckheimer = True              neg : pos    =      6.3 : 1.0
#                    wires = True              neg : pos    =      6.3 : 1.0
#                  matthau = True              neg : pos    =      6.3 : 1.0
#                   fabric = True              pos : neg    =      6.3 : 1.0
#              overwhelmed = True              pos : neg    =      6.3 : 1.0
#                      ugh = True              neg : pos    =      5.8 : 1.0
#                   doubts = True              pos : neg    =      5.8 : 1.0
#                     wits = True              pos : neg    =      5.7 : 1.0
